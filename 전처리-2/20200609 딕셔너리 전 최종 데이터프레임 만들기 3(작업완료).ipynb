# %%
import pandas as pd
all_sub_data = pd.read_csv('./data/all_sub_data.csv')
all_sub_data= df.fillna('')

# %%
type(eval(all_sub_data.head(1).menu[0]))
# Out:
# list

# %%
all_sub_data['menu'] = all_sub_data['menu'].apply(eval)

# %%
type(all_sub_data['menu'][0])
# Out:
# list

# %% [markdown]
# ## tf에 값 없으면 res_menu 에 식당 메뉴 넣기

# %%
for idx, i in enumerate(all_sub_data['tf']):
    if all_sub_data['tf'][idx] == '' :
        all_sub_data['tf'][idx] = all_sub_data['menu'][idx]
# Out:
# /home/team/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#체크
all_sub_data[all_sub_data['tf']=='']
#0 => 성공
# Out:
# Empty DataFrame
# Columns: [user_name, res_name, review, menu, PN, spicy, sweet, sour, saulty, mild, normal, for_vegitarian, for_mania, for_starter, indirec_mentioned, direc_mentioned, res_menus, tf]
# Index: []

# %% [markdown]
# ## 안쓰는 행 버리기

# %%
# all_sub_data.drop(['indirec_mentioned','direc_mentioned','res_menus	'], axis=1, inplace=True)

# %%
type(all_sub_data['tf'][0])
# Out:
# str

# %%
    if type(all_sub_data['tf'][idx]) == str :
        all_sub_data['tf'][idx] = all_sub_data['tf'][idx].replace(',',' ') 
        all_sub_data['tf'][idx] = all_sub_data['tf'][idx].split(' ')

# %%
all_sub_data.head()
# Out:
#                 user_name                        res_name  \
# 0  KgQnRvsPSrJJTOCp-reYZA  Seoul Garden Korean Restaurant
# 1  1goJa-4OKwc--vlISRm54g  Seoul Garden Korean Restaurant
# 2  6agrhhelmT9DLUfx4EeZVA  Seoul Garden Korean Restaurant
# 3  AvaeN3hgxdytAEMlNud-FQ  Seoul Garden Korean Restaurant
# 4  wML8YiFzB1JuCfyhPptiSg  Seoul Garden Korean Restaurant
#
#                                               review  \
# 0  we have been here three times now and have lov...
# 1  seoul garden was excellent  we moved to this a...
# 2  i like this place a lot one of the best korean...
# 3  korean barbecue at its finest the outside does...
# 4  food was ok the food looks good in pictures bu...
#
#                                                 menu  PN  spicy  sweet  sour  \
# 0  [bulgogi, galbigui, kimchijjigae, doenjangjjig...   0      1      0     0
# 1  [bulgogi, galbigui, kimchijjigae, doenjangjjig...   1      0      0     0
# ...

# %%
for idx in range(len(all_sub_data['tf'])) :
    if all_sub_data['tf'][idx][0] == '' :
            all_sub_data['tf'][idx] = all_sub_data['tf'][idx][1:]
# Out:
# /home/team/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
all_sub_data
# Out:
#                      user_name                        res_name  \
# 0       KgQnRvsPSrJJTOCp-reYZA  Seoul Garden Korean Restaurant
# 1       1goJa-4OKwc--vlISRm54g  Seoul Garden Korean Restaurant
# 2       6agrhhelmT9DLUfx4EeZVA  Seoul Garden Korean Restaurant
# 3       AvaeN3hgxdytAEMlNud-FQ  Seoul Garden Korean Restaurant
# 4       wML8YiFzB1JuCfyhPptiSg  Seoul Garden Korean Restaurant
# ...                        ...                             ...
# 110908               MrsOS2014    Sam Sam Korean Fried Chicken
# 110909                Alison A    Sam Sam Korean Fried Chicken
# 110910        addiction4travel    Sam Sam Korean Fried Chicken
# 110911                 152JoyB    Sam Sam Korean Fried Chicken
# 110912                   LC888    Sam Sam Korean Fried Chicken
#
#                                                    review  \
# 0       we have been here three times now and have lov...
# 1       seoul garden was excellent  we moved to this a...
# ...

# %%
all_sub_data.to_csv('./data/all_sub_data_all_list.csv',index=False)
