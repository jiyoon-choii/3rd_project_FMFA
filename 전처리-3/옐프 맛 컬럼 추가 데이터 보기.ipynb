# %%
import pandas as pd

# %%
df = pd.read_csv("./data/yelp_trip/yelp_final_add_taste.csv")

# %%
df["taste"].sample(20)
# Out:
# 38134                        notyet
# 22812                        notyet
# 42428                        notyet
# 61646                        notyet
# 11269                        notyet
# 30976                        notyet
# 51488                        notyet
# 34479                        notyet
# 51450                        notyet
# 58416                        notyet
# 50562                        notyet
# 27281                        notyet
# 48131                        notyet
# 28412                         spicy
# 35017    ['spicy', 'sweet', 'sour']
# 60939    ['spicy', 'sweet', 'sour']
# 55741                         spicy
# 70918                        notyet
# 62379                        notyet
# 53468                        notyet
# Name: taste, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77402 entries, 0 to 77401
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    77402 non-null  int64
#  1   Unnamed: 0.1  77402 non-null  int64
#  2   business_id   77402 non-null  object
#  3   date          77402 non-null  object
#  4   review_id     77402 non-null  object
#  5   stars         77402 non-null  object
#  6   user_id       77402 non-null  object
#  7   text          77402 non-null  object
#  8   categories    77402 non-null  object
#  9   city          77402 non-null  object
#  10  name          77402 non-null  object
#  11  state         77402 non-null  object
#  12  taste         77402 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 7.7+ MB

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1             business_id                 date  \
# 0               0            67  2AS4HuJJHTBG6R8D9ldrdA  2018-02-24 02:52:41
# 1               1            68  2AS4HuJJHTBG6R8D9ldrdA  2017-06-17 23:39:45
# 2               2            69  2AS4HuJJHTBG6R8D9ldrdA  2018-03-16 07:51:57
# 3               3            70  2AS4HuJJHTBG6R8D9ldrdA  2014-12-01 00:15:41
# 4               4            71  2AS4HuJJHTBG6R8D9ldrdA  2015-08-21 01:37:51
# ...           ...           ...                     ...                  ...
# 77397       77397        129725  59OgPGGzKFYqwSG_U06kuA  2019-12-10 02:10:44
# 77398       77398        129726  Mglgm8rfJxZ0LLgN23YGOg  2014-04-22 02:53:17
# 77399       77399        129727  Mglgm8rfJxZ0LLgN23YGOg  2013-03-05 21:15:24
# 77400       77400        129728  Mglgm8rfJxZ0LLgN23YGOg  2014-06-22 17:57:16
# 77401       77401        129729  Mglgm8rfJxZ0LLgN23YGOg  2015-03-28 14:19:47
#
# ...
