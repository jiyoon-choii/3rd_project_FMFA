# %%
def TitleName(name):
    for i,j in dir_food.items():
        if i == name:
#             print(i,j)
            return j

# %%
dir_food = \
{'갈비구이': 'galbigui',
 '갈치구이': 'galchigui',
 '고등어구이': 'godeungeogui',
 '곱창구이': 'gopchanggui',
 '닭갈비': 'dakgalbi',
 '더덕구이': 'deodeokgui',
 '떡갈비': 'tteokgalbi',
 '불고기': 'bulgogi',
 '삼겹살': 'samgyeopsal',
 '장어구이': 'jangeogui',
 '조개구이': 'jogaegui',
 '조기구이': 'jogigui',
 '황태구이': 'hwangtaegui',
 '훈제오리': 'hunjeori',
 '계란국': 'gyelangug',
 '떡국_만두국': 'tteokguk-mandutguk',
 '무국': 'muguk',
 '미역국': 'miyeokguk',
 '북엇국': 'bugeotguk',
 '시래기국': 'siraegiguk',
 '육개장': 'yukgaejang',
 '콩나물국': 'kongnamulguk',
 '과메기': 'gwamegi',
 '양념치킨': 'yangnyeomchicken',
 '젓갈': 'jeotgal',
 '콩자반': 'kongjaban',
 '편육': 'pyeonyuk',
 '피자': 'pizza',
 '후라이드치킨': 'friedchicken',
 '갓김치': 'gatkimchi',
 '깍두기': 'kkakdugi',
 '나박김치': 'nabakkimchi',
 '무생채': 'musaengchae',
 '배추김치': 'baechukimchi',
 '백김치': 'baekkimchi',
 '부추김치': 'buchukimchi',
 '열무김치': 'yeolmukimchi',
 '오이소박이': 'oisobagi',
 '총각김치': 'chonggakkimchi',
 '파김치': 'pakimchi',
 '가지볶음': 'gajibokkeum',
 '고사리나물': 'gosarinamul',
 '미역줄기볶음': 'miyeokjulgibokkeum',
 '숙주나물': 'sukjunamul',
 '시금치나물': 'sigeumchinamul',
 '애호박볶음': 'aehobakbokkeum',
 '경단': 'gyeongdan',
 '꿀떡': 'kkultteok',
 '송편': 'songpyeon',
 '만두': 'mandu',
 '라면': 'ramyeon',
 '막국수': 'makguksu',
 '물냉면': 'mulnaengmyeon',
 '비빔냉면': 'bibimnaengmyeon',
 '수제비': 'sujebi',
 '열무국수': 'yeolmuguksu',
 '잔치국수': 'janchiguksu',
 '짜장면': 'jajangmyeon',
 '짬뽕': 'jjamppong',
 '쫄면': 'jjolmyeon',
 '칼국수': 'kalguksu',
 '콩국수': 'kongguksu',
 '꽈리고추무침': 'kkwaligochumuchim',
 '도라지무침': 'dorajimuchim',
 '도토리묵': 'dotorimuk',
 '잡채': 'japchae',
 '콩나물무침': 'kongnamulmuchim',
 '홍어무침': 'hongeomuchim',
 '회무침': 'hoemuchim',
 '김밥': 'gimbap',
 '김치볶음밥': 'kimchibokkeumbap',
 '누룽지': 'nurungji',
 '비빔밥': 'bibimbap',
 '새우볶음밥': 'saeubokkeumbap',
 '알밥': 'albap',
 '유부초밥': 'yubuchobap',
 '잡곡밥': 'japgokbap',
 '주먹밥': 'jumeokbap',
 '감자채볶음': 'gamjachaebokkeum',
 '건새우볶음': 'geonsaeubokkeum',
 '고추장진미채볶음': 'gochujangjinmichaebokkeum',
 '두부김치': 'dubukimchi',
 '떡볶이': 'tteokbokki',
 '라볶이': 'rabokki',
 '멸치볶음': 'myeolchibokkeum',
 '소세지볶음': 'sausagebokkeum',
 '어묵볶음': 'eomukbokkeum',
 '오징어채볶음': 'ojingeochaebokkeum',
 '제육볶음': 'jeyukbokkeum',
 '주꾸미볶음': 'jukkumibokkeum',
 '보쌈': 'bossam',
 '수정과': 'sujeonggwa',
 '식혜': 'sikhye',
 '간장게장': 'ganjanggejang',
 '양념게장': 'yangnyeomgejang',
 '깻잎장아찌': 'kkaesipjangajji',
 '떡꼬치': 'tteokkkochi',
 '감자전': 'gamjajeon',
 '계란말이': 'gyeranmari',
 '계란후라이': 'gyeranfry',
 '김치전': 'kimchijeon',
 '동그랑땡': 'dongeurangttaeng',
 '생선전': 'saengseonjeon',
 '파전': 'pajeon',
 '호박전': 'hobakjeon',
 '곱창전골': 'gopchangjeongol',
 '갈치조림': 'galchijorim',
 '감자조림': 'gamjajorim',
 '고등어조림': 'godeungeojorim',
 '꽁치조림': 'kkongchijorim',
 '두부조림': 'dubujorim',
 '땅콩조림': 'ttangkongjorim',
 '메추리알장조림': 'mechurialjangjorim',
 '연근조림': 'yeongeunjorim',
 '우엉조림': 'ueongjorim',
 '장조림': 'jangjorim',
 '코다리조림': 'kodarijorim',
 '전복죽': 'jeonbokjuk',
 '호박죽': 'hobakjuk',
 '김치찌개': 'kimchijjigae',
 '닭계장': 'dakgyejang',
 '동태찌개': 'dongtaejjigae',
 '된장찌개': 'doenjangjjigae',
 '순두부찌개': 'sundubujjigae',
 '갈비찜': 'galbijjim',
 '계란찜': 'gyeranjjim',
 '김치찜': 'kimchijjim',
 '꼬막찜': 'kkomakjjim',
 '닭볶음탕': 'dakbokkeumtang',
 '수육': 'suyuk',
 '순대': 'sundae',
 '족발': 'jokbal',
 '찜닭': 'jjimdak',
 '해물찜': 'haemuljjim',
 '갈비탕': 'galbitang',
 '감자탕': 'gamjatang',
 '곰탕_설렁탕': 'gomguk-seolleongtang',
 '매운탕': 'maeuntang',
 '삼계탕': 'samgyetang',
 '추어탕': 'chueotang',
 '고추튀김': 'gochutwigim',
 '새우튀김': 'saeutwigim',
 '오징어튀김': 'ojingeotwigim',
 '약과': 'yakgwa',
 '약식': 'yaksik',
 '한과': 'hangwa',
 '멍게': 'meongge',
 '산낙지': 'sannakji',
 '물회': 'mulhoe',
 '육회': 'yukhoe'}

# %%
# OH 
OH = ['Seoul Garden Korean Restaurant', 'Bonchon - Seven Hills',
       'Ribsticks BBQ', 'BIBIBOP Asian Grill', 'Tree Country Bistro',
       'Seoul Hot Pot', 'Korea House', 'Mashiso Asian Grille',
       'Manna Korean Cuisine', 'Rising Grill Korean BBQ', 'Seoul Garden',
       'Hansol', 'Miega Restaurant', 'Lemon Grass']

# %%
# AB
AB=['Bonga Korean Restaurant', 'Koryo Korean Barbeque','Hodu Namu Korean Restaurant', 'Wow Chicken Chinatown',
       'Kiwa Korean Restaurant', 'Korean Village Restaurant',
       'Taste Of Korea', 'Koreana BBQ', 'Kim Chi House',
       'Sole Restaurant & Bar', 'Kim Chi', 'Lu Chai', 'Moon Korean BBQ',
       'The One Sushi', 'Crunchy House', 'Garosu Korean Restaurant',
       'Manrijangsung Korean Restaurant', 'Wow Chicken',
       'Thanh Long Noodle House', 'Olive Chicken', 'Macleod Sushi & BBQ',
       'Gogi Korean BBQ', 'Buk Chang Dong Soon Tofu Korean Restaurant',
       'Sura Korean Restaurant', 'Ssome Pocha', 'Migarock',
       'Yum Yum BBQ Chicken', 'Korean BBQ House', 'The Street Eatery',
       'Sudam Korean Restaurant', 'San Dong Banjeom',
       'To Go Square Korean Style Mealbox',
       'Fresh Blend Coffee & Sandwich Bar',
       'Insadong Korean BBQ Restaurant', 'Han Maru', 'Chimac', 'Anju',
       'Han Corea', 'Donday', 'Wayo Korean Restaurant',
       'K Town Fried Chicken', 'Namsan Korean Cuisine', 'Ogam Chicken',
       'Stone Bowl Korean Cuisine', 'Hankang Korean Restaurant',
       'Seoul Korean BBQ Restaurant',
       'Club House Family Restaurant & Lounge',
       'Anju Restaurant & Lounge', 'Soyummy Factory', 'Yum Yum BBQ',
       'SaVeg Cafe', 'Koryo Korean BBQ', 'Soban Korean BBQ',
       'Bowls Korean BBQ', 'The Red House', 'Maru Restaurant & Bar',
       'Bow Bulgogi House']

# %%
QC=['Kim Chi', 'Omma', 'Kagopa', 'Kimbob Cafe', 'Jumak', 'Seoul Chako',
       'Tianxia Restaurant Coreen', 'Bibiko', 'Be Bap', "Le K'Bob",
       'Mon Ami - Somerled', 'Kalbi', 'Comon', 'Mon Ami',
       'Pocha de Marie', 'Chingu', 'Bar Ganadara', 'Restaurant 5000 Ans',
       'Koryo', 'The Basak', 'Kiwa', 'Cinq Mille Ans', 'Atti Express',
       'Le Painnamou', 'Kantapia', 'KOYAJO', 'Restaurant Bok',
       'Sota BBQ Cor챕en', 'Opiano', 'La Maison Bulgogi', 'Chez Bong',
       'Resto DaMoa', 'Monami', 'Bol Orange', 'Mat챕 Latte', 'GaNaDaRa',
       'Bistro Boaboa', 'Hoya', 'Seoul BBQ', 'Ave Seoul', 'Hwang-Kum',
       'Atti Restaurant', 'Luna', 'Mon Ami - Sainte-Catherine',
       'TOV 4 Saisons', 'Hansang', "C'est si Bon", 'Koreana',
       'Beaumonde Par Mademoiselle', 'Koryo Barbecue Cor챕en', 'Matjip',
       'Hibi', 'K-BBQ', 'La Maison de Seoul', 'Resto So', 'Dadam',
       'Mon Ami Express', 'Rizpopotame', 'Kimpo', 'La Belle Cor챕e',
       'Mon Ami - Brossard', 'Manna', 'Sushi Jinjin', 'Kimchi',
       'Les Saisons de Cor챕e', 'Dae Jang Kum', 'SSAM', 'Woorijib', 'Maru',
       'Shabu Shabu', 'KimGalbi', 'DaWa', 'Chez Hwang']

# %%
# NC
NC=["Let's Meat Kbbq", 'Bonchon - Pineville', "Choi's Korea & Wing",
       'CO', 'Inter Korea', 'Korean Restaurant', 'The Improper Pig',
       'Seoul Food Meat Company', 'Hibiscus',
       'Gogi - A Korean Food Truck', 'Avenue Market',
       'Dae Bak Korean Restaurant', 'Bulgogi Box', "Miyagi's NoDa",
       'Iron Dish Korean BBQ', 'Bonchon - Woodlawn', 'Hiya Food Truck',
       'PePeRo', 'Cho Won Garden']

# %%
# WI
WI=['Bubble Island', 'Five Star Korean BBQ', 'Sujeo',
       'New Seoul Korean', 'Tipsy cow', "Sol's On the Square",
       'Mr.Kimchi Modern Korean', 'K Peppers', 'Saigon Noodles']

# %%
dic_f={'Seoul Garden Korean Restaurant': ['bulgogi',
  'galbigui',
  'kimchijjigae',
  'doenjangjjigae',
  'galbitang'],
 'Bonchon - Seven Hills': ['bulgogi',
  'bibimbap',
  'japchae',
  'tteokbokki',
  'mandu'],
 'Ribsticks BBQ': [''],
 'BIBIBOP Asian Grill': ['bibimbap'],
 'Tree Country Bistro': [''],
 'Seoul Hot Pot': [''],
 'Korea House': ['galbigui',
  'bibimbap',
  'pajeon',
  'gimbap',
  'kimchibokkeumbap',
  'yukgaejang'],
 'Mashiso Asian Grille': [''],
 'Manna Korean Cuisine': ['baechukimchi',
  'mandu',
  'saeutwigim',
  'gimbap',
  'ramyeon',
  'bulgogi',
  'jeyukbokkeum',
  'kimchibokkeumbap'],
 'Rising Grill Korean BBQ': ['sundubujjigae',
  'bibimbap',
  'kimchijjigae',
  'doenjangjjigae',
  'jjamppong',
  'pajeon',
  'tteokbokki'],
 'Seoul Garden': ['bulgogi',
  'bibimbap',
  'kimchijjigae',
  'galbigui',
  'samgyeopsal',
  'pajeon',
  'japchae'],
 'Hansol': ['gimbap', 'saeutwigim', 'dongeurangttaeng', 'hobakjeon'],
 'Miega Restaurant': ['jeyukbokkeum',
  'dubukimchi',
  'bulgogi',
  'samgyeopsal',
  'pajeon',
  'gimbap',
  'tteokbokki'],
 'Lemon Grass': [''],
 'Bonga Korean Restaurant': ['bossam',
  'jokbal',
  'friedchicken',
  'yangnyeomchicken',
  'saeutwigim'],
 'Koryo Korean Barbeque': ['samgyeopsal',
  'bulgogi',
  'galbigui',
  'doenjangjjigae'],
 'Hodu Namu Korean Restaurant': ['galbitang',
  'gamjatang',
  'bibimbap',
  'bulgogi',
  'kalguksu',
  'pajeon'],
 'Wow Chicken Chinatown': ['friedchicken', 'yangnyeomchicken'],
 'Kiwa Korean Restaurant': ['bulgogi', 'galbigui', 'japchae', 'pajeon'],
 'Korean Village Restaurant': ['bulgogi',
  'gamjatang',
  'japchae',
  'pajeon',
  'tteokbokki'],
 'Taste Of Korea': ['jokbal', 'bossam', 'makguksu', 'kalguksu', 'bibimbap'],
 'Koreana BBQ': ['bulgogi', 'galbigui', 'dakgalbi'],
 'Kim Chi House': ['japchae',
  'tteokbokki',
  'bibimbap',
  'sundubujjigae',
  'bulgogi',
  'jeyukbokkeum'],
 'Sole Restaurant & Bar': ['friedchicken',
  'baechukimchi',
  'bibimbap',
  'japchae'],
 'Kim Chi': ['japchae',
  'tteokbokki',
  'bibimbap',
  'sundubujjigae',
  'bulgogi',
  'jeyukbokkeum'],
 'Lu Chai': ['jajangmyeon', 'jjamppong'],
 'Moon Korean BBQ': ['galbigui',
  'dakgalbi',
  'ramyeon',
  'samgyeopsal',
  'janchiguksu',
  'gyeranjjim'],
 'The One Sushi': [''],
 'Crunchy House': ['friedchicken', 'bibimbap', 'jeyukbokkeum'],
 'Garosu Korean Restaurant': ['saeubokkeumbap',
  'bibimbap',
  'bulgogi',
  'tteokgalbi',
  'dakgalbi',
  'galbigui'],
 'Manrijangsung Korean Restaurant': ['jajangmyeon',
  'galbigui',
  'doenjangjjigae',
  'jjamppong',
  'tteokbokki'],
 'Wow Chicken': ['friedchicken', 'yangnyeomchicken'],
 'Thanh Long Noodle House': [''],
 'Olive Chicken': ['friedchicken', 'yangnyeomchicken'],
 'Macleod Sushi & BBQ': ['samgyeopsal', 'galbigui'],
 'Gogi Korean BBQ': ['samgyeopsal',
  'galbigui',
  'doenjangjjigae',
  'sundubujjigae',
  'japchae'],
 'Buk Chang Dong Soon Tofu Korean Restaurant': ['kimchijjigae',
  'sundubujjigae',
  'bulgogi',
  'galbigui'],
 'Sura Korean Restaurant': ['galbigui',
  'sundubujjigae',
  'bulgogi',
  'pajeon',
  'tteokbokki',
  'mandu'],
 'Ssome Pocha': ['galbigui',
  'bossam',
  'jokbal',
  'friedchicken',
  'tteokbokki',
  'jeyukbokkeum'],
 'Migarock': ['galbigui',
  'bossam',
  'bibimbap',
  'pajeon',
  'tteokbokki',
  'jeyukbokkeum'],
 'Yum Yum BBQ Chicken': ['galbigui',
  'friedchicken',
  'yangnyeomchicken',
  'japchae'],
 'Korean BBQ House': ['bulgogi',
  'samgyeopsal',
  'jeyukbokkeum',
  'galbigui',
  'galbitang'],
 'The Street Eatery': ['bibimbap'],
 'Sudam Korean Restaurant': ['sundubujjigae',
  'bibimbap',
  'jajangmyeon',
  'kimchijeon',
  'galbigui'],
 'San Dong Banjeom': ['jajangmyeon', 'jjamppong', 'friedchicken'],
 'To Go Square Korean Style Mealbox': ['gimbap',
  'bibimbap',
  'yangnyeomchicken',
  'jeyukbokkeum',
  'ramyeon'],
 'Fresh Blend Coffee & Sandwich Bar': ['bibimbap'],
 'Insadong Korean BBQ Restaurant': ['galbigui',
  'gamjatang',
  'jajangmyeon',
  'japchae'],
 'Han Maru': ['bibimbap', 'friedchicken', 'sundubujjigae', 'japchae'],
 'Chimac': ['yangnyeomchicken', 'friedchicken'],
 'Anju': ['yangnyeomchicken',
  'friedchicken',
  'kimchijeon',
  'gamjatang',
  'jjamppong'],
 'Han Corea': ['galbigui', 'dakgalbi', 'bulgogi', 'sundubujjigae', 'sundae'],
 'Donday': ['samgyeopsal',
  'pajeon',
  'doenjangjjigae',
  'kimchijeon',
  'galbigui'],
 'Wayo Korean Restaurant': ['samgyetang',
  'bulgogi',
  'jokbal',
  'tteokkkochi',
  'samgyeopsal',
  'galbigui'],
 'K Town Fried Chicken': ['yangnyeomchicken', 'friedchicken'],
 'Namsan Korean Cuisine': ['kimchibokkeumbap',
  'friedchicken',
  'yukgaejang',
  'dakgalbi',
  'galbitang'],
 'Ogam Chicken': ['samgyeopsal', 'friedchicken'],
 'Stone Bowl Korean Cuisine': ['bibimbap', 'bulgogi', 'jeyukbokkeum'],
 'Hankang Korean Restaurant': ['bibimbap', 'bulgogi', 'galbitang', 'galbigui'],
 'Seoul Korean BBQ Restaurant': ['galbigui'],
 'Club House Family Restaurant & Lounge': ['sundubujjigae',
  'doenjangjjigae',
  'galbijjim'],
 'Anju Restaurant & Lounge': ['myeolchibokkeum', 'saeutwigim', 'bibimbap'],
 'Soyummy Factory': ['gimbap', 'tteokbokki', 'jeyukbokkeum'],
 'Yum Yum BBQ': ['friedchicken', 'bulgogi'],
 'SaVeg Cafe': ['japchae', 'mandu', 'bibimbap'],
 'Koryo Korean BBQ': ['japchae', 'galbigui', 'bibimbap', 'bulgogi'],
 'Soban Korean BBQ': ['godeungeogui', 'galbigui', 'bibimbap', 'bulgogi'],
 'Bowls Korean BBQ': ['galbigui', 'bibimbap', 'bulgogi'],
 'The Red House': [''],
 'Maru Restaurant & Bar': ['galbigui', 'bibimbap', 'sundubujjigae'],
 'Bow Bulgogi House': ['jjamppong', 'gamjatang', 'sundubujjigae'],
 'Omma': ['kimchibokkeumbap', 'bulgogi', 'yangnyeomchicken'],
 'Kagopa': ['baechukimchi'],
 'Kimbob Cafe': ['galbigui', 'japchae'],
 'Jumak': ['friedchicken', 'pajeon', 'bulgogi'],
 'Seoul Chako': ['galbigui', 'mandu', 'bulgogi'],
 'Tianxia Restaurant Coreen': ['galbigui', 'jeyukbokkeum', 'bulgogi'],
 'Bibiko': ['galbigui', 'jeyukbokkeum', 'bulgogi', 'bibimbap', 'japchae'],
 'Be Bap': ['galbigui', 'bulgogi', 'bibimbap'],
 "Le K'Bob": ['friedchicken', 'yangnyeomchicken'],
 'Mon Ami - Somerled': ['friedchicken', 'sundubujjigae'],
 'Kalbi': ['samgyeopsal', 'galbigui'],
 'Comon': [''],
 'Mon Ami': ['friedchicken', 'sundubujjigae'],
 'Pocha de Marie': ['galbigui', 'bibimbap'],
 'Chingu': ['galbigui', 'kimchibokkeumbap', 'dakgalbi', 'mandu'],
 'Bar Ganadara': ['friedchicken'],
 'Restaurant 5000 Ans': [''],
 'Koryo': ['japchae', 'galbigui', 'bibimbap', 'bulgogi'],
 'The Basak': ['friedchicken', 'yangnyeomchicken'],
 'Kiwa': ['pajeon', 'galbigui', 'sundubujjigae'],
 'Cinq Mille Ans': 'None',
 'Atti Express': 'None',
 'Le Painnamou': 'None',
 'Kantapia': 'None',
 'KOYAJO': 'None',
 'Restaurant Bok': 'None',
 'Sota BBQ Cor챕en': 'None',
 'Opiano': 'None',
 'La Maison Bulgogi': 'None',
 'Chez Bong': 'None',
 'Resto DaMoa': 'None',
 'Monami': 'None',
 'Bol Orange': 'None',
 'Mat챕 Latte': 'None',
 'GaNaDaRa': 'None',
 'Bistro Boaboa': 'None',
 'Hoya': 'None',
 'Seoul BBQ': 'None',
 'Ave Seoul': 'None',
 'Hwang-Kum': 'None',
 'Atti Restaurant': 'None',
 'Luna': 'None',
 'Mon Ami - Sainte-Catherine': 'None',
 'TOV 4 Saisons': 'None',
 'Hansang': 'None',
 "C'est si Bon": 'None',
 'Koreana': 'None',
 'Beaumonde Par Mademoiselle': 'None',
 'Koryo Barbecue Cor챕en': 'None',
 'Matjip': 'None',
 'Hibi': 'None',
 'K-BBQ': 'None',
 'La Maison de Seoul': 'None',
 'Resto So': 'None',
 'Dadam': 'None',
 'Mon Ami Express': 'None',
 'Rizpopotame': 'None',
 'Kimpo': 'None',
 'La Belle Cor챕e': 'None',
 'Mon Ami - Brossard': 'None',
 'Manna': 'None',
 'Sushi Jinjin': 'None',
 'Kimchi': 'None',
 'Les Saisons de Cor챕e': 'None',
 'Dae Jang Kum': 'None',
 'SSAM': 'None',
 'Woorijib': 'None',
 'Maru': 'None',
 'Shabu Shabu': 'None',
 'KimGalbi': 'None',
 'DaWa': 'None',
 'Chez Hwang': 'None',
 "Let's Meat Kbbq": 'None',
 'Bonchon - Pineville': 'None',
 "Choi's Korea & Wing": 'None',
 'CO': 'None',
 'Inter Korea': 'None',
 'Korean Restaurant': 'None',
 'The Improper Pig': 'None',
 'Seoul Food Meat Company': 'None',
 'Hibiscus': 'None',
 'Gogi - A Korean Food Truck': 'None',
 'Avenue Market': 'None',
 'Dae Bak Korean Restaurant': 'None',
 'Bulgogi Box': 'None',
 "Miyagi's NoDa": 'None',
 'Iron Dish Korean BBQ': 'None',
 'Bonchon - Woodlawn': 'None',
 'Hiya Food Truck': 'None',
 'PePeRo': 'None',
 'Cho Won Garden': 'None',
 'Bubble Island': 'None',
 'Five Star Korean BBQ': 'None',
 'Sujeo': 'None',
 'New Seoul Korean': 'None',
 'Tipsy cow': 'None',
 "Sol's On the Square": 'None',
 'Mr.Kimchi Modern Korean': 'None',
 'K Peppers': 'None',
 'Saigon Noodles': 'None'}

# %%
Hyowon=OH+AB+QC+NC+WI

# %%
# dic={}
# for i in Hyowon:
#     dic[i] = 'None'

# %%
dic_f
# Out:
# {'Seoul Garden Korean Restaurant': ['bulgogi',
#   'galbigui',
#   'kimchijjigae',
#   'doenjangjjigae',
#   'galbitang'],
#  'Bonchon - Seven Hills': ['bulgogi',
#   'bibimbap',
#   'japchae',
#   'tteokbokki',
#   'mandu'],
#  'Ribsticks BBQ': [''],
#  'BIBIBOP Asian Grill': ['bibimbap'],
#  'Tree Country Bistro': [''],
#  'Seoul Hot Pot': [''],
#  'Korea House': ['galbigui',
#   'bibimbap',
#   'pajeon',
#   'gimbap',
#   'kimchibokkeumbap',
#   'yukgaejang'],
#  'Mashiso Asian Grille': [''],
#  'Manna Korean Cuisine': ['baechukimchi',
#   'mandu',
#   'saeutwigim',
#   'gimbap',
#   'ramyeon',
#   'bulgogi',
#   'jeyukbokkeum',
#   'kimchibokkeumbap'],
#  'Rising Grill Korean BBQ': ['sundubujjigae',
#   'bibimbap',
#   'kimchijjigae',
#   'doenjangjjigae',
#   'jjamppong',
#   'pajeon',
#   'tteokbokki'],
#  'Seoul Garden': ['bulgogi',
#   'bibimbap',
#   'kimchijjigae',
#   'galbigui',
#   'samgyeopsal',
#   'pajeon',
#   'japchae'],
# ...

# %%
def dic_cover(name,menu):
    name = str(name)
    
    dic_f[name]= menu

    print(dic_f[name])
#         print(i)
    return f'식당:{name}',dic_f[name]

# %%
# dir_n = str('Seoul Garden Korean Restaurant')
# dir_m =

# %%
# for i,j in enumerate(Hyowon):
#     if j == 'Koryo Korean Barbeque':
#         print(dic_f[j])
#         print(i,j)
# Out:
# ['samgyeopsal', 'bulgogi', 'galbigui', 'doenjangjjigae']
# 15 Koryo Korean Barbeque

# %%
len(OH+AB+QC+NC+WI)
# Out:
# 172

# %%
# 중복 검색
for i,j in enumerate(Hyowon):
    if j == 'Lu Chai':
        print(dic_f[j])
        print(i,j)
# Out:
# ['jajangmyeon', 'jjamppong']
# 25 Lu Chai

# %%
def TitleName(name):
    for i,j in dir_food.items():
        if i == name:
#             print(i,j)
            return j

# %%
def check_res(name):
    for i,j in enumerate(Hyowon):
        if j == name:
            print(dic_f[j])
            return i, j

# %%
check_res('Koryo Kalbi Korean')
# Koryo Kalbi Korean BBQ

# %%
dic_f['']=['']

# %%
len(OH),len(AB),len(QC),len(NC),len(WI)
# Out:
# (14, 57, 73, 19, 9)

# %%
172-92
# Out:
# 80

# %%
num=21
QC[num],Hyowon[14+57+num],check_res(Hyowon[14+57+num])
# Out:
# None
# ('Cinq Mille Ans', 'Cinq Mille Ans', (92, 'Cinq Mille Ans'))

# %%
Hyowon[14+57+num+1]
# Out:
# 'Atti Express'

# %%
name = input('검색 : ')
TitleName(name)
# Out:
# 검색 : 순두부찌개
# 'sundubujjigae'

# %%
dir_m = ['pajeon','galbigui','sundubujjigae']

# %%
# dir_n = input('가계 : ')
# dir_m = input('메뉴 : ')
dir_n = Hyowon[14+57+num]
dic_cover(dir_n, dir_m)
# Out:
# ['pajeon', 'galbigui', 'sundubujjigae']
# ('식당:Kiwa', ['pajeon', 'galbigui', 'sundubujjigae'])

# %%
dic_f
# Out:
# {'Seoul Garden Korean Restaurant': ['bulgogi',
#   'galbigui',
#   'kimchijjigae',
#   'doenjangjjigae',
#   'galbitang'],
#  'Bonchon - Seven Hills': ['bulgogi',
#   'bibimbap',
#   'japchae',
#   'tteokbokki',
#   'mandu'],
#  'Ribsticks BBQ': [''],
#  'BIBIBOP Asian Grill': ['bibimbap'],
#  'Tree Country Bistro': [''],
#  'Seoul Hot Pot': [''],
#  'Korea House': ['galbigui',
#   'bibimbap',
#   'pajeon',
#   'gimbap',
#   'kimchibokkeumbap',
#   'yukgaejang'],
#  'Mashiso Asian Grille': [''],
#  'Manna Korean Cuisine': ['baechukimchi',
#   'mandu',
#   'saeutwigim',
#   'gimbap',
#   'ramyeon',
#   'bulgogi',
#   'jeyukbokkeum',
#   'kimchibokkeumbap'],
#  'Rising Grill Korean BBQ': ['sundubujjigae',
#   'bibimbap',
#   'kimchijjigae',
#   'doenjangjjigae',
#   'jjamppong',
#   'pajeon',
#   'tteokbokki'],
#  'Seoul Garden': ['bulgogi',
#   'bibimbap',
#   'kimchijjigae',
#   'galbigui',
#   'samgyeopsal',
#   'pajeon',
#   'japchae'],
# ...

# %%
Mon Ami

# %%
dict((v, k) for k, v in map.iteritems())
