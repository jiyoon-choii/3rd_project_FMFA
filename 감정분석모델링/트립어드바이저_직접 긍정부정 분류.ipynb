# %% [markdown]
# # 목표 : stopword 만들기

# %%
import pandas as pd

# %%
trip = pd.read_csv("./data/trip_final.csv")

# %%
trip = trip.drop(["Unnamed: 0"], axis=1)

# %%
trip.head(3)
# Out:
#      user_name     res_name  rating  \
# 0    AppleTech  Korea House     5.0
# 1    NickyD202  Korea House     5.0
# 2  RCSColumbus  Korea House     5.0
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
# 2                             The Real Deal Korean
#
#                                               review  \
# 0  We’d never had Korean before and I’d been want...
# 1  I really was unsure of how much of the menu wo...
# 2  Absolutely delicious authentic Korean food ser...
#
#                               menu
# 0  ['kimchijjigae', 'samgyeopsal']
# 1  ['kimchijjigae', 'samgyeopsal']
# 2  ['kimchijjigae', 'samgyeopsal']

# %%
trip["P/N"] = None

# %%
trip.head(3)
# Out:
#      user_name     res_name  rating  \
# 0    AppleTech  Korea House     5.0
# 1    NickyD202  Korea House     5.0
# 2  RCSColumbus  Korea House     5.0
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
# 2                             The Real Deal Korean
#
#                                               review  \
# 0  We’d never had Korean before and I’d been want...
# 1  I really was unsure of how much of the menu wo...
# 2  Absolutely delicious authentic Korean food ser...
#
#                               menu   P/N
# 0  ['kimchijjigae', 'samgyeopsal']  None
# 1  ['kimchijjigae', 'samgyeopsal']  None
# 2  ['kimchijjigae', 'samgyeopsal']  None

# %%
trip_1000 = trip[:999]

# %%
len(trip_1000) # 1000개만 포함된 trip 데이터 프레임
# Out:
# 999

# %%
trip_10 = trip[:9]

# %%
for i, j in enumerate(trip_1000['review']):
    print(i, j)
    tmp = input("감성을 입력하세요")
    trip_1000["P/N"][i] = tmp
# Out:
# 0 We’d never had Korean before and I’d been wanting to try this for a while. We let our server know we’d never had it before and she gave us some recommendations. We ended up going with the beef bulgogi and the dolsot bibimbap. Both were great. It is important to know that some of the food is season to taste - so plan to add some of the table sauce and soy sauce to make it how you like it. The appetizer sides that came with each entree were great too. Service was excellent and everyone was very friendly. Lots of regulars while we were there.
# 감성을 입력하세요1
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# ...

# %%
trip_1000.to_csv("./data/trip_1000.csv")

# %%
trip_1000 = trip_1000.drop(["Unnamed: 0", "Unnamed: 0.1"], axis=1)

# %%
trip_1000.head(2)
# Out:
#    user_name     res_name  rating  \
# 0  AppleTech  Korea House     5.0
# 1  NickyD202  Korea House     5.0
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
#
#                                               review  \
# 0  We’d never had Korean before and I’d been want...
# 1  I really was unsure of how much of the menu wo...
#
#                               menu  P/N
# 0  ['kimchijjigae', 'samgyeopsal']  1.0
# 1  ['kimchijjigae', 'samgyeopsal']  1.0

# %%
trip_1000 = pd.read_csv("./data/trip_1000.csv")
trip_1000
# Out:
#      Unnamed: 0  Unnamed: 0.1            user_name              res_name  \
# 0             0             0            AppleTech           Korea House
# 1             1             1            NickyD202           Korea House
# 2             2             2          RCSColumbus           Korea House
# 3             3             3          Btravelfood           Korea House
# 4             4             4         cmcwhirter33           Korea House
# ..          ...           ...                  ...                   ...
# 994         994           994  secretgardenkohrong  Pyongyang Restaurant
# 995         995           995           RobinL2025  Pyongyang Restaurant
# 996         996           996             341jeans  Pyongyang Restaurant
# 997         997           997                Jim M  Pyongyang Restaurant
# 998         998           998             Cowpaper  Pyongyang Restaurant
#
#      rating                                        rev_title  \
# ...

# %%
import re

# %%
len(trip_1000)
# Out:
# 999

# %% [markdown]
# ## 특정 행의 값 바꿔주기

# %%
98 0로 입력  
103 1로 입력  
157 0로 입력  
174 1로 입력  
한국말이 포함된 언어는 빼기  
294 1로 입력  
430 0로 입력  
영어로 된게 아니면 빼기á  
494 0로 입력  
669 0로 입력

# %%
trip_1000["P/N"].iloc[98] = 0
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
trip_1000["P/N"].iloc[98]
# Out:
# 0.0

# %%
trip_1000["P/N"].iloc[103] = 1
trip_1000["P/N"].iloc[103]
# Out:
# 1.0

# %%
trip_1000["P/N"].iloc[157]
# Out:
# 0.0

# %%
trip_1000["P/N"].iloc[157] = 0
trip_1000["P/N"].iloc[157]
# Out:
# 0.0

# %%
trip_1000["P/N"].iloc[294]
# Out:
# 1.0

# %%
trip_1000["P/N"].iloc[294] = 1
trip_1000["P/N"].iloc[294]
# Out:
# 1.0

# %%
trip_1000["P/N"].iloc[430]
# Out:
# 1.0

# %%
trip_1000["P/N"].iloc[430] = 0
trip_1000["P/N"].iloc[430]
# Out:
# 0.0

# %%
trip_1000["P/N"].iloc[494]
# Out:
# 1.0

# %%
trip_1000["P/N"].iloc[494] = 0
trip_1000["P/N"].iloc[494]
# Out:
# 0.0

# %%
trip_1000["P/N"].iloc[669]
# Out:
# 0.0

# %% [markdown]
# ## trip_1000["P/N"]컬럼 int로 바꿔주기

# %% [markdown]
# - nan값이 있는 행이 있어서 int로 안바껴짐
# - nan값 있는 행을 찾아서 값 채워주기

# %%
trip_1000["P/N"] = trip_1000["P/N"].apply(pd.to_numeric)

# %%
trip_1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_name  999 non-null    object
#  1   res_name   999 non-null    object
#  2   rating     999 non-null    float64
#  3   rev_title  999 non-null    object
#  4   review     999 non-null    object
#  5   menu       999 non-null    object
#  6   P/N        998 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 54.8+ KB

# %%
trip_1000["P/N"]
# Out:
# 1.0    895
# 0.0    103
# Name: P/N, dtype: int64

# %%
trip_1000[(trip_1000["P/N"].isnull() == True)]
# Out:
#     user_name    res_name  rating       rev_title  \
# 174  adaajoku  비빔밥코리아 프라하     4.0  Delicious Food
#
#                                                 review          menu  P/N
# 174  I came here to eat after a quick look on here....  ['bibimbap']  NaN

# %%
trip_1000["P/N"].iloc[174] = 1
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
trip_1000["P/N"].iloc[174]
# Out:
# 1.0

# %%
trip_1000 = trip_1000.astype({'P/N': int})

# %%
trip_1000
# Out:
#                user_name              res_name  rating  \
# 0              AppleTech           Korea House     5.0
# 1              NickyD202           Korea House     5.0
# 2            RCSColumbus           Korea House     5.0
# 3            Btravelfood           Korea House     4.0
# 4           cmcwhirter33           Korea House     5.0
# ..                   ...                   ...     ...
# 994  secretgardenkohrong  Pyongyang Restaurant     4.0
# 995           RobinL2025  Pyongyang Restaurant     4.0
# 996             341jeans  Pyongyang Restaurant     3.0
# 997                Jim M  Pyongyang Restaurant     4.0
# 998             Cowpaper  Pyongyang Restaurant     3.0
#
#                                            rev_title  \
# 0    Fun and Authentic Experience with Great Service
# 1                            Get the seafood pancake
# 2                               The Real Deal Korean
# 3                                            Banchan
# ...

# %%
trip_1000.to_csv("./data/trip_yet.csv")

# %%
sentiment_1 = trip_1000[["review", "P/N"]]

# %%
sentiment_1
# Out:
#                                                 review  P/N
# 0    We’d never had Korean before and I’d been want...    1
# 1    I really was unsure of how much of the menu wo...    1
# 2    Absolutely delicious authentic Korean food ser...    1
# 3    The banchan or side dishes that they serve are...    1
# 4    My eleven year old twins beg to get biminbop o...    1
# ..                                                 ...  ...
# 994  This restaurant isn't somewhere you'd go parti...    1
# 995  Typical N.Korean food, including cold noodles....    0
# 996  we read the reviews and thought this would be ...    0
# 997  I took four friends to Pyongyang Restaurant fo...    1
# 998  Went here for dinner hoping it was the night t...    1
#
# [999 rows x 2 columns]

# %%
sentiment_1.to_csv("./data/sentiment_1.csv")

# %%
trip_yet = pd.read_csv("./data/trip_yet.csv")

# %%
trip_yet.iloc[998]
# Out:
# Unnamed: 0                                                  998
# user_name                                              Cowpaper
# res_name                                   Pyongyang Restaurant
# rating                                                        3
# rev_title                        Interesting ... but not great.
# review        Went here for dinner hoping it was the night t...
# menu                       ['mulnaengmyeon', 'bibimnaengmyeon']
# P/N                                                           1
# Name: 998, dtype: object

# %% [markdown]
# - 1000개를 또 가져와서 변수에 저장한 후 1000개 작업

# %%
trip_yet_2 = trip[999:2000]

# %%
trip_yet_3 = trip[2001:3000]
trip_yet_3
# Out:
#             user_name       res_name  rating  \
# 2001       Wanleeyana  유가네 닭갈비 명동1호점     4.0
# 2002        Sherbakes  유가네 닭갈비 명동1호점     4.0
# 2003          jbaniel  유가네 닭갈비 명동1호점     4.0
# 2004         glinghui  유가네 닭갈비 명동1호점     4.0
# 2005         Daniel A  유가네 닭갈비 명동1호점     5.0
# ...               ...            ...     ...
# 2995    KalleBorgholm        Arirang     4.0
# 2996       kylecagula        Arirang     5.0
# 2997            Ewa B        Arirang     5.0
# 2998         Jurgen S        Arirang     4.0
# 2999  ShariWestSussex        Arirang     3.0
#
#                                               rev_title  \
# 2001                         Delicious food alert here!
# 2002                            Yummy hot plate chicken
# 2003                    Yoogane in General - For groups
# 2004                                             Yumm 😊
# 2005  I read the reviews and found the difficult to ...
# ...                                                 ...
# ...

# %%
trip_yet_2
# Out:
#               user_name              res_name  rating  \
# 999       Traveltubbies  Pyongyang Restaurant     3.0
# 1000        WilliamBaek  Pyongyang Restaurant     5.0
# 1001          n0butakai  Pyongyang Restaurant     3.0
# 1002         Lai Yoke L  Pyongyang Restaurant     3.0
# 1003          hanneetan  Pyongyang Restaurant     3.0
# ...                 ...                   ...     ...
# 1995        anne_spacey         유가네 닭갈비 명동1호점     3.0
# 1996           Ningchou         유가네 닭갈비 명동1호점     3.0
# 1997            Vicky Q         유가네 닭갈비 명동1호점     2.0
# 1998             Tina L         유가네 닭갈비 명동1호점     5.0
# 1999  DonJYLoveToTravel         유가네 닭갈비 명동1호점     5.0
#
#                                              rev_title  \
# 999   An interesting introduction to North Korean food
# 1000                                       Great Taste
# 1001    Typical North Korean restaurant for non-Korean
# 1002                                     Worth a visit
# ...

# %% [markdown]
# ## 직접 긍정부정 값 채워넣기

# %%
for i, j in enumerate(trip_yet_2['review']):
    print(i, j)
    tmp = input("감성을 입력하세요")
    trip_yet_2["P/N"][i] = tmp
# Out:
# 0 Our first dining experience in a North Korean restaurant, totally run and operated by women folks from North Korea. If you are there for dinner, you could get to enjoy the performances - traditional and modern from waitresses that double up as performers. Waitresses were friendly and despite the fact that they have to multi-task, did not slow down the service.
#
# The whole experience was quite strange. Food wise, that's not too bad at all but I would not return just for the food and the performance. Once is good enough.
# 감성을 입력하세요1
# C:\Users\admin\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# ...

# %%
78행 0로 변경
109행 1로 변경
119행 0로 변경
884행~893행
963행 1로 변경

# %%
trip_yet_2
# Out:
#               user_name              res_name  rating  \
# 999       Traveltubbies  Pyongyang Restaurant     3.0
# 1000        WilliamBaek  Pyongyang Restaurant     5.0
# 1001          n0butakai  Pyongyang Restaurant     3.0
# 1002         Lai Yoke L  Pyongyang Restaurant     3.0
# 1003          hanneetan  Pyongyang Restaurant     3.0
# ...                 ...                   ...     ...
# 1995        anne_spacey         유가네 닭갈비 명동1호점     3.0
# 1996           Ningchou         유가네 닭갈비 명동1호점     3.0
# 1997            Vicky Q         유가네 닭갈비 명동1호점     2.0
# 1998             Tina L         유가네 닭갈비 명동1호점     5.0
# 1999  DonJYLoveToTravel         유가네 닭갈비 명동1호점     5.0
#
#                                              rev_title  \
# 999   An interesting introduction to North Korean food
# 1000                                       Great Taste
# 1001    Typical North Korean restaurant for non-Korean
# 1002                                     Worth a visit
# ...

# %%
trip_yet_2["P/N"].iloc[157]
